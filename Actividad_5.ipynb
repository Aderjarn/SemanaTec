# %% [markdown]
# # Actividad - Librería `pandas`

# %% [markdown]
# * **Nombre:** Fabián Avilés Cortés
# * **Matrícula:** A01367678

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Entregar:** Archivo PDF de la actividad, así como el archivo .ipynb en tu repositorio.
# **Nota:** Recuerda habrá una penalización de **50** puntos si la actividad fue entregada fuera de la fecha límite.

# %% [markdown]
# 1. Subir el archivo `netflix_titles.csv` que se encuentra en el repositorio de la clase y cargalos en un `DataFrame`.

# %%
df = pd.read_csv('netflix_titles.csv')

# %% [markdown]
# 2. Desplegar las primeras 5 líneas del `DataFrame`.

# %%
df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# 3. Implementa una función que despliegue el primer renglon de un `DataFrame`.

# %%
def the_first(df):
  return df[0:1]

the_first(df)
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %% [markdown]
# 4. Implementa una función que regrese el número de registros en el `DataFrame`.

# %%
def row_number(df):
  return len(df.index)

row_number(df)
# Out:
# 7787

# %% [markdown]
# 5. Implementa una función que despliega las películas con un `release_year` determinado.

# %%
def released_year(year,df):
  return df[df['release_year'] == year]

year_query = 2009
released_year(year_query,df)
# Out:
#      show_id     type                title               director  \
# 3         s4    Movie                    9            Shane Acker
# 72       s73    Movie             17 Again            Burr Steers
# 100     s101    Movie             3 Idiots        Rajkumar Hirani
# 226     s227    Movie        A Serious Man  Ethan Coen, Joel Coen
# 229     s230    Movie         A Single Man               Tom Ford
# ...      ...      ...                  ...                    ...
# 7678   s7679  TV Show           WWII in HD                    NaN
# 7727   s7728    Movie  You Changed My Life    Cathy Garcia-Molina
# 7748   s7749    Movie            الف مبروك      Ahmed Nader Galal
# 7763   s7764    Movie                Zenda         Avadhoot Gupte
# 7778   s7779    Movie           Zombieland        Ruben Fleischer
#
#                                                    cast  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 72    Zac Efron, Leslie Mann, Matthew Perry, Thomas ...
# 100   Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...
# 226   Michael Stuhlbarg, Richard Kind, Fred Melamed,...
# 229   Colin Firth, Julianne Moore, Nicholas Hoult, G...
# ...                                                 ...
# 7678  Gary Sinise, Rob Lowe, Josh Lucas, Justin Bart...
# 7727  John Lloyd Cruz, Sarah Geronimo, Rayver Cruz, ...
# 7748  Ahmed Helmy, Laila Ezz El Arab, Mahmoud El Fis...
# 7763  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# 7778  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
#
#                                     country         date_added  release_year  \
# 3                             United States  November 16, 2017          2009
# 72                            United States    January 1, 2021          2009
# 100                                   India     August 1, 2019          2009
# 226   United States, United Kingdom, France   January 16, 2018          2009
# 229                           United States  November 11, 2019          2009
# ...                                     ...                ...           ...
# 7678                          United States        May 2, 2020          2009
# 7727                            Philippines  February 27, 2019          2009
# 7748                                  Egypt     April 25, 2020          2009
# 7763                                  India  February 15, 2018          2009
# 7778                          United States   November 1, 2019          2009
#
#      rating  duration                                          listed_in  \
# 3     PG-13    80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 72    PG-13   102 min                                           Comedies
# 100   PG-13   164 min             Comedies, Dramas, International Movies
# 226       R   106 min                       Comedies, Independent Movies
# 229       R   100 min           Dramas, Independent Movies, LGBTQ Movies
# ...     ...       ...                                                ...
# 7678  TV-14  1 Season                                         Docuseries
# 7727  TV-PG   116 min             Comedies, Dramas, International Movies
# 7748  TV-14   115 min             Comedies, Dramas, International Movies
# 7763  TV-14   120 min                       Dramas, International Movies
# 7778      R    88 min                            Comedies, Horror Movies
#
#                                             description
# 3     In a postapocalyptic world, rag-doll robots hi...
# 72    Nearing a midlife crisis, thirty-something Mik...
# 100   While attending one of India's premier college...
# 226   With every aspect of his life unraveling, a Je...
# 229   This stream-of-consciousness drama centers on ...
# ...                                                 ...
# 7678  Rare color footage interwoven with firsthand i...
# 7727  Laida and Miggy think they've found perfect ha...
# 7748  On his wedding day, an arrogant, greedy accoun...
# 7763  A change in the leadership of a political part...
# 7778  Looking to survive in a world taken over by zo...
#
# [137 rows x 12 columns]

# %% [markdown]
# 6. Implementa una función que despliegue las películas que son de un país determinado.

# %%
def origin_country(country, df):
  return df[df['country'] == country]

country_query = 'India'
origin_country(country_query,df)
# Out:
#      show_id   type                     title            director  \
# 8         s9  Movie                       706       Shravan Kumar
# 9        s10  Movie                      1920        Vikram Bhatt
# 18       s19  Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21  Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22  Movie              ​Goli Soda 2        Vijay Milton
# ...      ...    ...                       ...                 ...
# 7764   s7765  Movie                      Zero          Aanand Rai
# 7769   s7770  Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7776   s7777  Movie                  Zokkomon    Satyajit Bhatkal
# 7780   s7781  Movie                       Zoo        Shlok Sharma
# 7783   s7784  Movie                    Zubaan         Mozez Singh
#
#                                                    cast country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# 9     Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India
# 18    Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...   India
# 20    Geetanjali Thapa, Zain Khan Durrani, Shray Rai...   India
# 21    Samuthirakani, Bharath Seeni, Vinoth, Esakki B...   India
# ...                                                 ...     ...
# 7764  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...   India
# 7769  Hrithik Roshan, Abhay Deol, Farhan Akhtar, Kat...   India
# 7776  Darsheel Safary, Anupam Kher, Manjari Fadnis, ...   India
# 7780  Shashank Arora, Shweta Tripathi, Rahul Kumar, ...   India
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#               date_added  release_year rating duration  \
# 8          April 1, 2019          2019  TV-14  118 min
# 9      December 15, 2017          2008  TV-MA  143 min
# 18        March 29, 2019          2019  TV-14  124 min
# 20     September 1, 2018          2018  TV-14  110 min
# 21    September 15, 2018          2018  TV-14  128 min
# ...                  ...           ...    ...      ...
# 7764        May 21, 2019          2018  TV-14  159 min
# 7769   December 15, 2019          2011  TV-14  154 min
# 7776    November 1, 2018          2011     PG  104 min
# 7780        July 1, 2018          2018  TV-MA   94 min
# 7783       March 2, 2019          2015  TV-14  111 min
#
#                                              listed_in  \
# 8                  Horror Movies, International Movies
# 9       Horror Movies, International Movies, Thrillers
# 18                Comedies, Dramas, Independent Movies
# 20    Dramas, Independent Movies, International Movies
# 21    Action & Adventure, Dramas, International Movies
# ...                                                ...
# 7764            Comedies, Dramas, International Movies
# 7769            Comedies, Dramas, International Movies
# 7776                  Children & Family Movies, Dramas
# 7780  Dramas, Independent Movies, International Movies
# 7783    Dramas, International Movies, Music & Musicals
#
#                                             description
# 8     When a doctor goes missing, his psychiatrist w...
# 9     An architect and his wife move into a castle t...
# 18    On India's Independence Day, a zany mishap in ...
# 20    After accidentally connecting over the Interne...
# 21    A taxi driver, a gangster and an athlete strug...
# ...                                                 ...
# 7764  Through his relationships with two wildly diff...
# 7769  Three friends on an adventurous road trip/bach...
# 7776  When his cruel uncle abandons him, a young orp...
# 7780  A drug dealer starts having doubts about his t...
# 7783  A scrappy but poor boy worms his way into a ty...
#
# [923 rows x 12 columns]

# %% [markdown]
# 7. Crea un nuevo `DataFrame` que sólo contenga las columnas `type`, `title`, `country` y `release_year`.

# %%
dfEdited = df[['type', 'title', 'country', 'release_year']]
dfEdited
# Out:
#          type                                    title  \
# 0     TV Show                                       3%
# 1       Movie                                     7:19
# 2       Movie                                    23:59
# 3       Movie                                        9
# 4       Movie                                       21
# ...       ...                                      ...
# 7782    Movie                                     Zozo
# 7783    Movie                                   Zubaan
# 7784    Movie                        Zulu Man in Japan
# 7785  TV Show                    Zumbo's Just Desserts
# 7786    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                                 country  release_year
# 0                                                Brazil          2020
# 1                                                Mexico          2016
# 2                                             Singapore          2011
# 3                                         United States          2009
# 4                                         United States          2008
# ...                                                 ...           ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...          2005
# 7783                                              India          2015
# 7784                                                NaN          2019
# 7785                                          Australia          2019
# 7786              United Kingdom, Canada, United States          2019
#
# [7787 rows x 4 columns]

# %% [markdown]
# 8. Despliega, cuantos tipos de producciones (`type`) se hicieron por país determinado (`country`).

# %%
dfEdited.groupby(['country', 'type']).size().reset_index(name='Suma')
# Out:
#                                                country     type  Suma
# 0                                            Argentina    Movie    34
# 1                                            Argentina  TV Show    16
# 2    Argentina, Brazil, France, Poland, Germany, De...    Movie     1
# 3                                     Argentina, Chile    Movie     1
# 4                               Argentina, Chile, Peru    Movie     1
# ..                                                 ...      ...   ...
# 768                                          Venezuela    Movie     1
# 769                                Venezuela, Colombia    Movie     1
# 770                                            Vietnam    Movie     5
# 771                                       West Germany    Movie     1
# 772                                           Zimbabwe    Movie     1
#
# [773 rows x 3 columns]

# %% [markdown]
# # 9. Implementa la función que genera el cuadrado de un número.

# %%
def square(x):
  return x*x

# %% [markdown]
# 10. Usando el método `apply`, genera el cuadrado de todos los valores del siguiente `DataFrame`.

# %%
df2 = pd.DataFrame({'A': [1, 2, 3, 5, 6], 'B': [10, 20, 30, 40, 50]})
df2.apply(square)
# Out:
#     A     B
# 0   1   100
# 1   4   400
# 2   9   900
# 3  25  1600
# 4  36  2500
